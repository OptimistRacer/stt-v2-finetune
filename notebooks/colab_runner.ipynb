# %% [markdown]
# # STT v2 Day 1 (GPU) runner
#
# Before running: copy the `stt-v2-finetune` repo folder into your Google Drive (either via manual sync,
# or `git clone` from a private GitHub remote if one has been set up), and make sure
# `outputs/clean/*.wav` + `outputs/manifest.jsonl` from the local prep step are inside it too.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
REPO_DIR = '/content/drive/MyDrive/stt-v2-finetune'  # edit if your Drive path differs
# %cd $REPO_DIR

# %%
# !pip install -q -r requirements-colab.txt

# %%
import os
os.environ['HF_TOKEN'] = ''  # paste your HuggingFace token (must have accepted pyannote/speaker-diarization-3.1 terms)

# %%
# !python scripts/run_day1_gpu.py --config configs/day1.yaml

# %% [markdown]
# Output: `outputs/manifest_day1_complete.jsonl` with `speaker` and `draft_transcript` filled in.
# Copy it (and the `outputs/clips/` folder) back down for Day 2 manual correction.
